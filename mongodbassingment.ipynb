# %%
# what is mongodb? explain non relational databases in short. in which scenarios it is preffered to use mongodb  over sql database.
'''
mongodb is a document based database used to build highly available and scalable internet application , mongodb is open source 
NoSQL database management program.
NoSQL is non relational database allow structure and semistructure data to be stored and  manipulated.
mongodb used when large dataset constantly changed as sql work on static dataset.
'''

# %%
# state and explain features of mongodb.
'''
mongodb is a non-relational document database that provide support for JSON like storage. the mongodb database has a flexible
data model that enables you to store unstructure data.
feature of mongodb:
1. schema-less database: it means one collection can hold different types of document in it.
2. Document oriented: data are stored in document instead of table.
3.indexing: in this every field in document  are indexed which make it easier and take less time to search data from pool of data.
4.scalability: it is hotizontally scalable with the help of sharding.sharding means to distribute data on multiple server.
5.replication: mongodb supports master slave replication 
master can perform reads and writes and a slave copies data from master and can only be used for reads.
'''

# %%
# write a code to connect mongodb to python.also create a database and collection in mongodb.
'''
for connecting mongodb in pyhton
pip install pymango
import pymongo
myclient = pymango.MongoClient("mongodb://localhost:27017/")
mydb = myclient["mydatabase"]
mycol = mydb["customers"]
'''

# %%
# using database and collection cretaed in question number 3, write a code to insert one record and insert many records,
#use the find() and find_one() to print the inserted records.
'''
import pymongo

myclient = pymongo.MongoClient("mongodb://localhost:27017/")
mydb = myclient["mydatabase"]
mycol = mydb["customers"]

mydict = { "name": "John", "address": "Highway 37" }

x = mycol.insert_one(mydict)

'''
'''
import pymongo

myclient = pymongo.MongoClient("mongodb://localhost:27017/")
mydb = myclient["mydatabase"]
mycol = mydb["customers"]

mylist = [
  { "name": "Amy", "address": "Apple st 652"},
  { "name": "Hannah", "address": "Mountain 21"},
  { "name": "Michael", "address": "Valley 345"},
  { "name": "Sandy", "address": "Ocean blvd 2"},
  { "name": "Betty", "address": "Green Grass 1"},
  { "name": "Richard", "address": "Sky st 331"},
  { "name": "Susan", "address": "One way 98"},
  { "name": "Vicky", "address": "Yellow Garden 2"},
  { "name": "Ben", "address": "Park Lane 38"},
  { "name": "William", "address": "Central st 954"},
  { "name": "Chuck", "address": "Main Road 989"},
  { "name": "Viola", "address": "Sideway 1633"}
]

x = mycol.insert_many(mylist)

print(x.inserted_ids)
'''
'''
import pymongo

myclient = pymongo.MongoClient("mongodb://localhost:27017/")
mydb = myclient["mydatabase"]
mycol = mydb["customers"]

x = mycol.find_one()

print(x)
'''

'''
import pymongo

myclient = pymongo.MongoClient("mongodb://localhost:27017/")
mydb = myclient["mydatabase"]
mycol = mydb["customers"]

for x in mycol.find():
  print(x)
'''

# %%
# explain how you can use the find() method to query the mongodb database.write a simple code to demonstarte this.
'''
To select data from a table in MongoDB, we use the find() method.The find() method returns all occurrences in the selection.
first parameter of the find() method is a query object.

db.inventory.insert_one(
    {
        "item": "canvas",
        "qty": 100,
        "tags": ["cotton"],
        "size": {"h": 28, "w": 35.5, "uom": "cm"},
    }
)

cursor = db.inventory.find({"item": "canvas"})

'''

# %%
# explain sort method . give an example to demonstrate sorting in mongodb.
'''
sort() method are used to sort the result in ascending and descending order.sort() method takes one parameter for "fieldname"
and one parameter for "direction".

import pymongo

myclient = pymongo.MongoClient("mongodb://localhost:27017/")
mydb = myclient["mydatabase"]
mycol = mydb["customers"]

mydoc = mycol.find().sort("name")

for x in mydoc:
  print(x)

'''

# %%
# explain why delete_one(),delete_many(),and drop() is used.
'''
delete_one() used to delete one document, the first parameter of delete_one() method is a  query object defining which document
to delete.
delete_many() used to delete more than one document, the first parameter of delete_many() method is a query object defining which 
document to delete.
drop() used to delete a table, or collection as it is called in MongoDB by using drop() method.drop() method return true if collection
was dropped successfully, and false if the collection does not exists.
'''
